# %%
import numpy as np
import os
import pandas as pd

# %%
data = np.load(os.path.join(os.path.dirname(os.getcwd()), "data", "feat_train_stock_indexes.npy"), allow_pickle=True)

# %%
data.shape
# Out:
# (4,)

# %%
new_data = []
for i in range(data.shape[0]):
    new_data.append(data[i].tolist())

# %%
new_data[0]
# Out:
# [[0.024561197304491245,
#   0.018396767590920682,
#   0.013250607948981141,
#   0.0008805499206401279,
#   0.001920379811527262,
#   -0.010192454132848638],
#  [-0.008546656363888516,
#   -0.007934829362437945,
#   -0.0018733413982321423,
#   -0.007463275824166615,
#   0.0009552460841302235,
#   -0.0006381801979102875],
#  [0.012479169251809807,
#   -0.012088592750917115,
#   0.04282784619820568,
#   0.02719404637787637,
#   0.026729935262678417,
#   0.03810742489571517],
#  [0.04278796219285752,
#   -0.00412632891707343,
#   0.03986539778483511,
#   0.02734795983004812,
#   0.01112782129832901,
#   0.02032489094067813],
#  [-0.02675629215195663,
#   0.001767769420640164,
#   -0.02632910779701625,
#   -0.018706662240652427,
#   -0.013148634269231074,
#   -0.018761356180833744],
#  [0.002660474325931972,
#   -0.0042132056668009454,
#   0.004326262594688046,
#   -0.005370652059957237,
#   -0.00439597894777588,
#   -0.009837860112497765],
#  [0.040176490211733196,
# ...

# %%
pd.DataFrame(new_data[1])
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.003258  0.005235  0.016147  0.009104  0.005016  0.025738  0.003597
# 1    -0.006973 -0.007054 -0.015160 -0.002653 -0.022501 -0.020878  0.008823
# 2    -0.003066  0.011862 -0.023581  0.009764  0.022674  0.013131 -0.006418
# 3    -0.000988  0.006432 -0.016271  0.026643 -0.031601 -0.002576 -0.004180
# 4     0.002497 -0.002770 -0.007993  0.023853 -0.001195 -0.006503 -0.008826
# ...        ...       ...       ...       ...       ...       ...       ...
# 5384  0.007905  0.003205  0.010048 -0.005445  0.001521 -0.010302  0.002078
# 5385 -0.019699  0.000853 -0.007306 -0.000449 -0.022063 -0.002049 -0.014109
# 5386  0.004704  0.006955 -0.003712  0.003838  0.009857 -0.007299  0.025457
# 5387 -0.001655  0.000000  0.000269  0.002667  0.008580  0.003688  0.000000
# 5388 -0.020411 -0.013382 -0.018057 -0.003557 -0.023096  0.002569 -0.012266
#
#             7         8         9         10        11        12
# ...

# %%
X = np.array( [ [[ 1, 6, 7, 1], [ 2, 12, 14, 2]], [[ 5, 9, 2], [10, 18, 4]] ] )
X.shape
# Out:
# <ipython-input-53-3a6803adbee5>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.array( [ [[ 1, 6, 7, 1], [ 2, 12, 14, 2]], [[ 5, 9, 2], [10, 18, 4]] ] )
# (2, 2)
